# %%
import yut.engine
from example_player import ExamplePlayer
import math
import random
import numpy as np

# %%
distance_to_goal = np.zeros( yut.rule.FINISHED+1 )
outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=5)

for _ in range(10):
	for s in range(yut.rule.FINISHED):
		weighted_sum = 0.0
		for outcome, prob in zip( outcomes, probs ):
			pos = s
			for ys in outcome:
				pos = yut.rule.next_position( pos, ys, True )
			weighted_sum += ( 1 + distance_to_goal[pos] ) * prob 
		distance_to_goal[s] = weighted_sum

class MinimaxPlayer(yut.engine.Player):
    def __init__(self, max_depth=2):
        """
        Initialize the Minimax player with configurable search depth
        
        Args:
            max_depth (int): Maximum depth to search in the game tree
        """
        self.max_depth = max_depth
    
    def _evaluate_board_state(self, my_positions, enemy_positions):
        my_duplicates = [ sum(np == p for np in my_positions) for p in my_positions ]
        enemy_duplicates = [ sum(np == p for np in enemy_positions) for p in enemy_positions ]
        # multipliers = [ 1, 0.85, 0.7, 0.55, 0.4 ] # best aginst random player
        multipliers = [ 1, 1, 0.7, 0.4, 0.3 ] # best aginst example player
     
        return - sum( distance_to_goal[p] * (multipliers[np] if p != 0 else 1) for p,np in zip(my_positions,my_duplicates) ) \
                + sum( distance_to_goal[p] * (multipliers[np] if p != 0 else 1) for p,np in zip(enemy_positions,enemy_duplicates) ) \
    
    def _is_shortcut_possible(self, position):
        shortcut_positions = {15, 22, 29} 
        return position in shortcut_positions
    
    def minimax(self, my_positions, enemy_positions, available_yutscores, depth, is_maximizing):
        """
        Minimax algorithm with robust move validation
        
        Args:
            my_positions (list): Current player's piece positions
            enemy_positions (list): Opponent's piece positions
            available_yutscores (list): Available move distances
            depth (int): Current search depth
            is_maximizing (bool): Whether it's maximizing player's turn
        
        Returns:
            tuple: (best_score, best_move)
        """
        # Terminal conditions
        if depth == 0:
            return self._evaluate_board_state(my_positions, enemy_positions), None
        
        # Determine current player's positions based on turn
        current_positions = my_positions if is_maximizing else enemy_positions
        # other_positions = enemy_positions if is_maximizing else my_positions
        
        best_score = float('-inf') if is_maximizing else float('inf')
        best_move = None
        
        # Filter out invalid move combinations beforehand
        for mal_index, mal_pos in enumerate(current_positions):
            if mal_pos == yut.rule.FINISHED:
                continue
            
    
            for ys in available_yutscores:
                shortcuts = [True, False] if self._is_shortcut_possible(mal_pos) else [False]
                
                for shortcut in shortcuts:        
                    # Simulate move with error handling
                    if is_maximizing:
                        legal_move, next_my_positions, next_enemy_positions, mal_caught = yut.rule.make_move(
                            my_positions, enemy_positions, mal_index, ys, shortcut
                        )
                    else:
                        legal_move, next_enemy_positions, next_my_positions, mal_caught = yut.rule.make_move(
                            enemy_positions, my_positions, mal_index, ys, shortcut
                        )
                    
                    if not legal_move:
                        continue
            
                    # Recursive minimax call
                    scores = []
                    outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=1)
                    for outcome, prob in zip(outcomes, probs):
                        for next_ys in outcome:
                            score, _ = self.minimax(next_my_positions, next_enemy_positions, [next_ys], depth - 1, not is_maximizing)
                      
                            scores.append(score) 
                            
                          
                    # Update best score and move
                    score = np.max(scores) if is_maximizing else np.min(scores)
                    
                    if is_maximizing:
                        if score > best_score:
                            best_score = score
                            best_move = (mal_index, ys, shortcut)
                    else:
                        if score < best_score:
                            best_score = score
                            best_move = (mal_index, ys, shortcut)
        
        return best_score, best_move

    def action(self, state):
        """
        Determine the best action for the current game state
        
        Args:
            state (tuple): Current game state 
                           (turn, my_positions, enemy_positions, available_yutscores)
        
        Returns:
            tuple: Move details (mal_index, yut_score, shortcut, extra_info)
        """
        _, my_positions, enemy_positions, available_yutscores = state
        # Run minimax to find best move
        _, best_move = self.minimax(my_positions, enemy_positions, available_yutscores, depth=self.max_depth, is_maximizing=True)
        
        # If no valid move found, return a default move
        if best_move is None:
            # Try to find any legal move
            for mal_index, mal_pos in enumerate(my_positions):
                if mal_pos == yut.rule.FINISHED:
                    continue
                for ys in available_yutscores:
                    for shortcut in [True, False]:
                        legal_move, _, _, _ = yut.rule.make_move(my_positions, enemy_positions, mal_index, ys, shortcut)
                        if legal_move:
                            return mal_index, ys, shortcut, ""
            
            # Absolute fallback
            return 0, available_yutscores[0], True, ""
        
        return best_move[0], best_move[1], best_move[2], ""
    
    
    def name(self):
        return "Robust Minimax Player"
    
    def on_my_action(self, state, my_action, result):
        pass

# %%
import numpy as np
class RandomPlayer(yut.engine.Player):
	def name(self):
		return "Random"

	def action(self, state):
		turn, my_positions, enemy_positions, available_yutscores = state
		yutscore_to_use = np.random.choice( available_yutscores )
		available_mals = []
		if yutscore_to_use == -1:
			available_mals = [ mal_index for mal_index,mal_position in enumerate(my_positions) if mal_position != yut.rule.FINISHED and mal_position != 0 ]
		if len(available_mals) == 0:
			available_mals = [ mal_index for mal_index,mal_position in enumerate(my_positions) if mal_position != yut.rule.FINISHED ]
		mal_to_move = np.random.choice( available_mals )
		shortcut = True
		debug_msg = ""

		return mal_to_move, yutscore_to_use, shortcut, debug_msg

# %%
distance_to_goal = np.zeros(yut.rule.FINISHED + 1)
outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=5)

for _ in range(10):
    for s in range(yut.rule.FINISHED - 1, -1, -1):
        weighted_sum = 0.0
        for outcome, prob in zip(outcomes, probs):
            pos = s
            for ys in outcome:
                pos = yut.rule.next_position(pos, ys, True)
            weighted_sum += (1 + distance_to_goal[pos]) * prob
        distance_to_goal[s] = weighted_sum


def evaluate_score(my_positions, enemy_positions, throw_again):
    my_duplicates = [sum(np == p for np in my_positions) for p in my_positions]
    enemy_duplicates = [sum(np == p for np in enemy_positions) for p in enemy_positions]
    multipliers = [1, 1, 0.7, 0.4, 0.3]

    return -sum(
        distance_to_goal[p] * (multipliers[np] if p != 0 else 1)
        for p, np in zip(my_positions, my_duplicates)
    ) + sum(
        distance_to_goal[p] * (multipliers[np] if p != 0 else 1)
        for p, np in zip(enemy_positions, enemy_duplicates)
    ) + (+1 if throw_again else 0)

# %%
yut.rule.FINISHED
# Out:
# 30

# %%
# Pre-compute distance-to-goal values
distance_to_goal = np.zeros(yut.rule.FINISHED + 1)
outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=5)

for _ in range(200):
    for s in range(yut.rule.FINISHED - 1, -1, -1):
        weighted_sum = 0.0
        for outcome, prob in zip(outcomes, probs):
            pos = s
            for ys in outcome:
                pos = yut.rule.next_position(pos, ys, True)
            weighted_sum += (1 + distance_to_goal[pos]) * prob
        distance_to_goal[s] = weighted_sum




class HeuristicPlayer(yut.engine.Player):
    def name(self):
        return "HeuristicImproved"
    
    def evaluate_score(my_positions, enemy_positions, throw_again):
        my_duplicates = [sum(np == p for np in my_positions) for p in my_positions]
        enemy_duplicates = [sum(np == p for np in enemy_positions) for p in enemy_positions]
        multipliers = [1, 1, 0.7, 0.4, 0.3]  # For evaluating based on the distance

        vulnerable_map = {0: [], 1: [], 2: [0], 3:[0, 1], 4: [1, 2], 5: [2, 3], 6:[3, 4], 7:[4], 8:[6], 9: [6,7], 10: [7,8], 
                          11: [], 12:[10], 13:[], 14:[5], 15:[10,11,5,13], 16: [13,14], 17:[14], 18:[8,9], 19:[9], 20:[18], 
                          21:[18,19], 22:[19,20,16], 23:[11,12], 24:[12,15], 25:[20,21,16,17], 26:[17,21,22], 27:[22,25], 28:[25,26], 29:[26,27], 30:[]}

        capture_bonus = 0.05  # Bonus for capturing an enemy's mal
        shortcut_bonus = 0  # Bonus for landing on a shortcut position
        landing_penalty = -0.001


        # Uncomment for default
        # capture_bonus = 0  # Bonus for capturing an enemy's mal
        # shortcut_bonus = 0  # Bonus for landing on a shortcut position
        # landing_penalty = 0
    
        

        # Initialize evaluation score
        evaluation = 0

        # Evaluate the player's positions
        for p, np in zip(my_positions, my_duplicates):
            multiplier = multipliers[np] if p != 0 else 1
            evaluation -= distance_to_goal[p] * multiplier
            
            # Add bonus for capturing an enemy's mal
            if p in enemy_positions:
                evaluation += capture_bonus
            # Penalize if the player's mal is 2 or 3 tiles ahead of any enemy piece
            for enemy_pos in enemy_positions:
                if enemy_pos in vulnerable_map[p]:
                    evaluation += landing_penalty*len(vulnerable_map[p])
        
        # Evaluate the enemy's positions
        for p, np in zip(enemy_positions, enemy_duplicates):
            multiplier = multipliers[np] if p != 0 else 1
            evaluation += distance_to_goal[p] * multiplier

            # Add penalty for the enemy capturing a mal
            if p in my_positions:
                evaluation += capture_bonus
            # Penalize if the enemy's mal is 2 or 3 tiles ahead of our piece
            for my_pos in my_positions:
                if my_pos in vulnerable_map[p]:
                    evaluation -= landing_penalty*len(vulnerable_map[p])

        return evaluation
    
    def _is_shortcut_possible(self, position):
        shortcut_positions = {15, 22, 29} 
        return position in shortcut_positions

    def action(self, state):
        turn, my_positions, enemy_positions, available_yutscores = state

        # Evaluate all possible moves and choose the best one
        best_score = -float('inf')
        best_action = None

        for mi, mp in enumerate(my_positions):
            if mp == yut.rule.FINISHED:
                continue
            for ys in available_yutscores:
                shortcuts = [True, False] if self._is_shortcut_possible(mi) else [False]

                for shortcut in shortcuts:
                    legal_move, next_my_positions, next_enemy_positions, num_mals_caught = yut.rule.make_move(
                        my_positions, enemy_positions, mi, ys, shortcut
                    )
                    if legal_move:
                        # Calculate the score for this move
                        throw_again = num_mals_caught > 0
                        score = evaluate_score(next_my_positions, next_enemy_positions, throw_again)

                        # Heuristic adjustments
                        # if throw_again:
                        #     score += 0.01  # Encourage moves that allow another turn
                        # if num_mals_caught > 0:
                        #     score += 0.05  # Reward capturing an opponent's mal

                        # Prioritize finishing a mal
                        if next_my_positions[mi] == yut.rule.FINISHED:
                            score += 0.01

                        # Update best move
                        if score > best_score:
                            best_score = score
                            best_action = (mi, ys, shortcut)

        # Return the best action
        if best_action is not None:
            return best_action[0], best_action[1], best_action[2], ""

        # Fallback (no legal moves)
        return 0, available_yutscores[0], False, ""

# %%
distance_to_goal = np.zeros( yut.rule.FINISHED+1 )

outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=2)

for _ in range(200):
	for s in range(yut.rule.FINISHED):
		weighted_sum = 0.0
		for outcome, prob in zip( outcomes, probs ):
			pos = s
			for ys in outcome:
				pos = yut.rule.next_position( pos, ys, True )
			weighted_sum += ( 1 + distance_to_goal[pos] ) * prob 
		distance_to_goal[s] = weighted_sum

class MinimaxYethuPlayer(yut.engine.Player):
    def __init__(self, max_depth=2):
        """
        Initialize the Minimax player with configurable search depth
        
        Args:
            max_depth (int): Maximum depth to search in the game tree
        """
        self.max_depth = max_depth
    
    def _evaluate_board_state(self, my_positions, enemy_positions, mal_caught):
        my_duplicates = [sum(np == p for np in my_positions) for p in my_positions]
        enemy_duplicates = [sum(np == p for np in enemy_positions) for p in enemy_positions]
        multipliers = [1, 1, 0.7, 0.4, 0.3]  # For evaluating based on the distance

        vulnerable_map = {0: [], 1: [], 2: [0], 3:[0, 1], 4: [1, 2], 5: [2, 3], 6:[3, 4], 7:[4], 8:[6], 9: [6,7], 10: [7,8], 
                          11: [], 12:[10], 13:[], 14:[5], 15:[10,11,5,13], 16: [13,14], 17:[14], 18:[8,9], 19:[9], 20:[18], 
                          21:[18,19], 22:[19,20,16], 23:[11,12], 24:[12,15], 25:[20,21,16,17], 26:[17,21,22], 27:[22,25], 28:[25,26], 29:[26,27], 30:[]}

        capture_bonus = 0.05  # Bonus for capturing an enemy's mal
        shortcut_bonus = 0  # Bonus for landing on a shortcut position
        landing_penalty = -0.01


        # Uncomment for default
        # capture_bonus = 0  # Bonus for capturing an enemy's mal
        # shortcut_bonus = 0  # Bonus for landing on a shortcut position
        # landing_penalty = 0
    
        

        # Initialize evaluation score
        evaluation = 0

        # Evaluate the player's positions
        for p, np in zip(my_positions, my_duplicates):
            multiplier = multipliers[np] if p != 0 else 1
            evaluation -= distance_to_goal[p] * multiplier
            
            # Add bonus for capturing an enemy's mal
            if p in enemy_positions:
                evaluation += capture_bonus
            # Penalize if the player's mal is 2 or 3 tiles ahead of any enemy piece
            for enemy_pos in enemy_positions:
                if enemy_pos in vulnerable_map[p]:
                    evaluation += landing_penalty*len(vulnerable_map[p])
        
        # Evaluate the enemy's positions
        for p, np in zip(enemy_positions, enemy_duplicates):
            multiplier = multipliers[np] if p != 0 else 1
            evaluation += distance_to_goal[p] * multiplier

            # Add penalty for the enemy capturing a mal
            if p in my_positions:
                evaluation += capture_bonus
            # Penalize if the enemy's mal is 2 or 3 tiles ahead of our piece
            for my_pos in my_positions:
                if my_pos in vulnerable_map[p]:
                    evaluation -= landing_penalty*len(vulnerable_map[p])

        return evaluation

    
    def _is_shortcut_possible(self, position):
        shortcut_positions = {15, 22, 29} 
        return position in shortcut_positions
    
    # def minimax(self, my_positions, enemy_positions, available_yutscores, depth, is_maximizing):
    #     """
    #     Minimax algorithm with robust move validation
        
    #     Args:
    #         my_positions (list): Current player's piece positions
    #         enemy_positions (list): Opponent's piece positions
    #         available_yutscores (list): Available move distances
    #         depth (int): Current search depth
    #         is_maximizing (bool): Whether it's maximizing player's turn
        
    #     Returns:
    #         tuple: (best_score, best_move)
    #     """
    #     # Terminal conditions
    #     if depth == 0:
    #         return self._evaluate_board_state(my_positions, enemy_positions), None
        
    #     # Determine current player's positions based on turn
    #     current_positions = my_positions if is_maximizing else enemy_positions
    #     # other_positions = enemy_positions if is_maximizing else my_positions
        
    #     best_score = float('-inf') if is_maximizing else float('inf')
    #     best_move = None
        
    #     # Filter out invalid move combinations beforehand
    #     for mal_index, mal_pos in enumerate(current_positions):
    #         # mal_index --> Which mal
    #         # mal_pos --> the location in the map
    #         if mal_pos == yut.rule.FINISHED:
    #             continue
            
    
    #         for ys in available_yutscores:
    #             # ys we can choose
    #             shortcuts = [True] if self._is_shortcut_possible(mal_pos) else [False]
                
    #             for shortcut in shortcuts:        
    #                 # Simulate move with error handling
    #                 if is_maximizing:
    #                     legal_move, next_my_positions, next_enemy_positions, mal_caught = yut.rule.make_move(
    #                         my_positions, enemy_positions, mal_index, ys, shortcut
    #                     )
    #                 else:
    #                     legal_move, next_enemy_positions, next_my_positions, mal_caught = yut.rule.make_move(
    #                         enemy_positions, my_positions, mal_index, ys, shortcut
    #                     )
                    
    #                 if not legal_move:
    #                     continue
                        
    #                 # Recursive minimax call
    #                 scores = []
    #                 outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=1)
                    
    #                 for outcome, prob in zip(outcomes, probs):
    #                     for next_ys in outcome:
    #                         score, _ = self.minimax(next_my_positions, next_enemy_positions, [next_ys], depth - 1, not is_maximizing)

    #                         score *= (1.06)**mal_caught
                            

    #                         #___________________________________________________________________________________________________________________________________________
    #                         vulnerable_map = {0: [], 1: [], 2: [0], 3:[0, 1], 4: [1, 2], 5: [2, 3], 6:[3, 4], 7:[4], 8:[6], 9: [6,7], 10: [7,8], 
    #                                             11: [], 12:[10], 13:[], 14:[5], 15:[10,11,5,13], 16: [13,14], 17:[14], 18:[8,9], 19:[9], 20:[18], 
    #                                             21:[18,19], 22:[19,20,16], 23:[11,12], 24:[12,15], 25:[20,21,16,17], 26:[17,21,22], 27:[22,25], 28:[25,26], 29:[26,27], 30:[]}
                            
    #                         for pos in next_enemy_positions:
    #                             if pos in vulnerable_map[pos]:
    #                                 score *= 0.95

    #                         score *= probs

    #                         #_____________________________________________________________________________________________________________________________________________
    #                         scores.append(score) 
                            
                          
    #                 # Update best score and move
    #                 score = np.max(scores) if is_maximizing else np.min(scores)
                    
    #                 if is_maximizing:
    #                     if score > best_score:
    #                         best_score = score
    #                         best_move = (mal_index, ys, shortcut)
    #                 else:
    #                     if score < best_score:
    #                         best_score = score
    #                         best_move = (mal_index, ys, shortcut)
        
    #     return best_score, best_move

    # def action(self, state):
    #     """
    #     Determine the best action for the current game state
        
    #     Args:
    #         state (tuple): Current game state 
    #                        (turn, my_positions, enemy_positions, available_yutscores)
        
    #     Returns:
    #         tuple: Move details (mal_index, yut_score, shortcut, extra_info)
    #     """
    #     _, my_positions, enemy_positions, available_yutscores = state
    #     # Run minimax to find best move
    #     _, best_move = self.minimax(my_positions, enemy_positions, available_yutscores, depth=self.max_depth, is_maximizing=True)
        
    #     # If no valid move found, return a default move
    #     if best_move is None:
    #         # Try to find any legal move
    #         for mal_index, mal_pos in enumerate(my_positions):
    #             if mal_pos == yut.rule.FINISHED:
    #                 continue
    #             for ys in available_yutscores:
    #                 for shortcut in [True, False]:
    #                     legal_move, _, _, _ = yut.rule.make_move(my_positions, enemy_positions, mal_index, ys, shortcut)
    #                     if legal_move:
    #                         return mal_index, ys, shortcut, ""
            
    #         # Absolute fallback
    #         return 0, available_yutscores[0], True, ""
        
    #     return best_move[0], best_move[1], best_move[2], ""

    def minimax(self, my_positions, enemy_positions, available_yutscores, depth, alpha, beta, is_maximizing, mal_caught):
        """
        Minimax algorithm with Alpha-Beta Pruning and robust move validation.
        
        Args:
            my_positions (list): Current player's piece positions.
            enemy_positions (list): Opponent's piece positions.
            available_yutscores (list): Available move distances.
            depth (int): Current search depth.
            alpha (float): Best score that the maximizing player can guarantee.
            beta (float): Best score that the minimizing player can guarantee.
            is_maximizing (bool): Whether it's maximizing player's turn.
        
        Returns:
            tuple: (best_score, best_move)
        """
        # Terminal condition: if depth is 0, return board evaluation
        if depth == 0:
            return self._evaluate_board_state(my_positions, enemy_positions, mal_caught), None

        # Determine current player's positions
        current_positions = my_positions if is_maximizing else enemy_positions

        best_score = float('-inf') if is_maximizing else float('inf')
        best_move = None

        for mal_index, mal_pos in enumerate(current_positions):
            # Skip finished pieces
            if mal_pos == yut.rule.FINISHED:
                continue

            for ys in available_yutscores:
                # Check shortcut possibility
                shortcuts = [True, False] if self._is_shortcut_possible(mal_pos) else [False]

                for shortcut in shortcuts:
                    # Simulate the move
                    if is_maximizing:
                        legal_move, next_my_positions, next_enemy_positions, mal_caught = yut.rule.make_move(
                            my_positions, enemy_positions, mal_index, ys, shortcut
                        )
                    else:
                        legal_move, next_enemy_positions, next_my_positions, mal_caught = yut.rule.make_move(
                            enemy_positions, my_positions, mal_index, ys, shortcut
                        )

                    if not legal_move:
                        continue

                    # Recursive call to minimax with Alpha-Beta Pruning
                    scores = []
                    outcomes, probs = yut.rule.enumerate_all_cast_outcomes(depth=1)

                    for outcome, prob in zip(outcomes, probs):
                        for next_ys in outcome:
                            score, _ = self.minimax(
                                next_my_positions, 
                                next_enemy_positions, 
                                [next_ys], 
                                depth - 1, 
                                alpha, 
                                beta, 
                                not is_maximizing,
                                mal_caught
                            )

                            
                            scores.append(score)
                    # Calculate the best score based on the player's role
                    score = np.max(scores) if is_maximizing else np.min(scores)

                    # Update best score and best move
                    if is_maximizing:
                        if score > best_score:
                            best_score = score
                            best_move = (mal_index, ys, shortcut)

                        # Alpha-Beta Pruning
                        alpha = max(alpha, best_score)
                        if alpha >= beta:
                            return best_score, best_move  # Prune remaining branches
                    else:
                        if score < best_score:
                            best_score = score
                            best_move = (mal_index, ys, shortcut)

                        # Alpha-Beta Pruning
                        beta = min(beta, best_score)
                        if beta <= alpha:
                            return best_score, best_move  # Prune remaining branches

        return best_score, best_move

    def action(self, state):
        """
        Determine the best action for the current game state.
        
        Args:
            state (tuple): Current game state 
                        (turn, my_positions, enemy_positions, available_yutscores)
        
        Returns:
            tuple: Move details (mal_index, yut_score, shortcut, extra_info)
        """
        _, my_positions, enemy_positions, available_yutscores = state
        # Run minimax with Alpha-Beta Pruning to find the best move
        _, best_move = self.minimax(
            my_positions, enemy_positions, available_yutscores, 
            depth=self.max_depth, 
            alpha=float('-inf'), 
            beta=float('inf'), 
            is_maximizing=True,
            mal_caught=0
        )

        # If no valid move found, return a default move
        if best_move is None:
            # Try to find any legal move
            for mal_index, mal_pos in enumerate(my_positions):
                if mal_pos == yut.rule.FINISHED:
                    continue
                for ys in available_yutscores:
                    for shortcut in [True, False]:
                        legal_move, _, _, _ = yut.rule.make_move(my_positions, enemy_positions, mal_index, ys, shortcut)
                        if legal_move:
                            return mal_index, ys, shortcut, ""

            # Absolute fallback
            return 0, available_yutscores[0], True, ""

        return best_move[0], best_move[1], best_move[2], ""

    
    
    def name(self):
        return "Minimax Player"

# %%
# create a game engine
engine = yut.engine.GameEngine()

# create two game players
player1 = MinimaxYethuPlayer()
player2 = ExamplePlayer()

# simulate a game between two players with a given random seed
num_trial = 1000
win_rate = 0
for random_seed in range(num_trial):
	winner = engine.play( player1, player2, seed=random_seed )
	if winner == 0:
		win_rate += 1
		print( str(random_seed) + ": Player 1 won!" )
	else:
		print( str(random_seed) + ": Player 2 won!" )

print("Player 1 wins " + str(win_rate) + " times, with winrate of " + str(win_rate/num_trial) )
# Out:
# 0: Player 2 won!
# 1: Player 2 won!
# 2: Player 2 won!
# 3: Player 2 won!
# 4: Player 2 won!
# 5: Player 2 won!
# 6: Player 2 won!
# 7: Player 2 won!
# 8: Player 2 won!
# 9: Player 1 won!
# 10: Player 1 won!
# 11: Player 1 won!
# 12: Player 2 won!
# 13: Player 2 won!
# 14: Player 2 won!
# 15: Player 2 won!
# 16: Player 1 won!
# 17: Player 2 won!
# 18: Player 1 won!
# 19: Player 1 won!
# 20: Player 1 won!
# 21: Player 2 won!
# 22: Player 2 won!
# 23: Player 1 won!
# 24: Player 2 won!
# 25: Player 1 won!
# 26: Player 1 won!
# 27: Player 2 won!
# 28: Player 1 won!
# 29: Player 1 won!
# 30: Player 2 won!
# 31: Player 2 won!
# 32: Player 1 won!
# 33: Player 2 won!
# 34: Player 2 won!
# 35: Player 1 won!
# 938: Player 2 won!
# 939: Player 2 won!
# 940: Player 2 won!
# 941: Player 2 won!
# 942: Player 2 won!
# 943: Player 1 won!
# 944: Player 1 won!
# 945: Player 2 won!
# 946: Player 1 won!
# 947: Player 1 won!
# 948: Player 2 won!
# 949: Player 2 won!
# 950: Player 2 won!
# 951: Player 1 won!
# 952: Player 2 won!
# 953: Player 2 won!
# 954: Player 1 won!
# 955: Player 1 won!
# 956: Player 1 won!
# 957: Player 2 won!
# 958: Player 1 won!
# 959: Player 2 won!
# 960: Player 1 won!
# 961: Player 1 won!
# 962: Player 2 won!
# 963: Player 1 won!
# 964: Player 2 won!
# 965: Player 1 won!
# 966: Player 2 won!
# 967: Player 2 won!
# 968: Player 2 won!
# 969: Player 2 won!
# 970: Player 2 won!
# 971: Player 1 won!
# 972: Player 2 won!
# 973: Player 1 won!
# 974: Player 1 won!
# 975: Player 1 won!
# 976: Player 1 won!
# 977: Player 1 won!
# 978: Player 2 won!
# 979: Player 2 won!
# 980: Player 1 won!
# 981: Player 2 won!
# 982: Player 1 won!
# 983: Player 2 won!
# 984: Player 2 won!
# 985: Player 2 won!
# 986: Player 1 won!
# 987: Player 2 won!
# 988: Player 1 won!
# 989: Player 2 won!
# 990: Player 1 won!
# 991: Player 2 won!
# 992: Player 1 won!
# 993: Player 1 won!
# 994: Player 1 won!
# 995: Player 2 won!
# 996: Player 2 won!
# 997: Player 1 won!
# 998: Player 2 won!
# 999: Player 1 won!
# Player 1 wins 494 times, with winrate of 0.494

# %%
# create a game engine
engine = yut.engine.GameEngine()

# create two game players
player1 = HeuristicPlayer()
player2 = ExamplePlayer()

# simulate a game between two players with a given random seed
num_trial = 2500
win_rate = 0
for random_seed in range(num_trial):
	winner = engine.play( player1, player2, seed=random_seed )
	if winner == 0:
		win_rate += 1
		print( str(random_seed) + ": Player 1 won!" )
	else:
		print( str(random_seed) + ": Player 2 won!" )

print("Player 1 wins " + str(win_rate) + " times, with winrate of " + str(win_rate/num_trial) )
# Out:
# 0: Player 2 won!
# 1: Player 1 won!
# 2: Player 2 won!
# 3: Player 2 won!
# 4: Player 2 won!
# 5: Player 1 won!
# 6: Player 2 won!
# 7: Player 1 won!
# 8: Player 2 won!
# 9: Player 2 won!
# 10: Player 1 won!
# 11: Player 1 won!
# 12: Player 2 won!
# 13: Player 2 won!
# 14: Player 1 won!
# 15: Player 2 won!
# 16: Player 1 won!
# 17: Player 1 won!
# 18: Player 2 won!
# 19: Player 1 won!
# 20: Player 2 won!
# 21: Player 1 won!
# 22: Player 1 won!
# 23: Player 1 won!
# 24: Player 2 won!
# 25: Player 2 won!
# 26: Player 1 won!
# 27: Player 2 won!
# 28: Player 2 won!
# 29: Player 2 won!
# 30: Player 2 won!
# 31: Player 2 won!
# 32: Player 1 won!
# 33: Player 2 won!
# 34: Player 2 won!
# 35: Player 1 won!
# 36: Player 2 won!
# 37: Player 2 won!
# 38: Player 1 won!
# 39: Player 1 won!
# 40: Player 2 won!
# 41: Player 1 won!
# 42: Player 2 won!
# 43: Player 1 won!
# 817: Player 2 won!
# 818: Player 1 won!
# 819: Player 1 won!
# 820: Player 2 won!
# 821: Player 1 won!
# 822: Player 1 won!
# 823: Player 2 won!
# 824: Player 2 won!
# 825: Player 1 won!
# 826: Player 2 won!
# 827: Player 1 won!
# 828: Player 2 won!
# 829: Player 2 won!
# 830: Player 2 won!
# 831: Player 1 won!
# 832: Player 2 won!
# 833: Player 1 won!
# 834: Player 1 won!
# 835: Player 1 won!
# 836: Player 1 won!
# 837: Player 1 won!
# 838: Player 2 won!
# 839: Player 2 won!
# 840: Player 2 won!
# 841: Player 1 won!
# 842: Player 1 won!
# 843: Player 2 won!
# 844: Player 2 won!
# 845: Player 1 won!
# 846: Player 2 won!
# 847: Player 1 won!
# 848: Player 2 won!
# 849: Player 2 won!
# 850: Player 2 won!
# 851: Player 2 won!
# 852: Player 2 won!
# 853: Player 2 won!
# 854: Player 2 won!
# 855: Player 1 won!
# 856: Player 2 won!
# 857: Player 1 won!
# 858: Player 2 won!
# 859: Player 1 won!
# 860: Player 1 won!
# 861: Player 1 won!
# 862: Player 1 won!
# 863: Player 2 won!
# 864: Player 2 won!
# 865: Player 1 won!
# 866: Player 1 won!
# 867: Player 1 won!
# 868: Player 2 won!
# 869: Player 2 won!
# 870: Player 1 won!
# 871: Player 1 won!
# 872: Player 1 won!
# 873: Player 2 won!
# 874: Player 1 won!
# 875: Player 2 won!
# 876: Player 2 won!
# 877: Player 1 won!
# 878: Player 1 won!
# 879: Player 1 won!
# 880: Player 1 won!
# 881: Player 2 won!
# 882: Player 1 won!
# 883: Player 2 won!
# 884: Player 1 won!
# 885: Player 1 won!
# 886: Player 1 won!
# 887: Player 1 won!
# 888: Player 1 won!
# 889: Player 1 won!
# 890: Player 2 won!
# 891: Player 2 won!
# 892: Player 1 won!
# 893: Player 1 won!
# 894: Player 2 won!
# 895: Player 2 won!
# 896: Player 1 won!
# 897: Player 1 won!
# 898: Player 1 won!
# 899: Player 2 won!
# 900: Player 2 won!
# 901: Player 1 won!
# 902: Player 2 won!
# 903: Player 1 won!
# 904: Player 2 won!
# 905: Player 2 won!
# 906: Player 1 won!
# 907: Player 2 won!
# 908: Player 2 won!
# 909: Player 1 won!
# 910: Player 1 won!
# 911: Player 1 won!
# 912: Player 1 won!
# 913: Player 2 won!
# 914: Player 1 won!
# 915: Player 1 won!
# 916: Player 1 won!
# 917: Player 2 won!
# 918: Player 2 won!
# 919: Player 1 won!
# 920: Player 2 won!
# 921: Player 1 won!
# 922: Player 1 won!
# 923: Player 2 won!
# 924: Player 1 won!
# 925: Player 2 won!
# 926: Player 1 won!
# 927: Player 2 won!
# 928: Player 2 won!
# 929: Player 1 won!
# 930: Player 1 won!
# 931: Player 2 won!
# 932: Player 1 won!
# 933: Player 1 won!
# 934: Player 1 won!
# 935: Player 1 won!
# 936: Player 2 won!
# 937: Player 2 won!
# 938: Player 1 won!
# 939: Player 2 won!
# 940: Player 1 won!
# 941: Player 1 won!
# 942: Player 2 won!
# 943: Player 1 won!
# 944: Player 2 won!
# 2495: Player 1 won!
# 2496: Player 1 won!
# 2497: Player 2 won!
# 2498: Player 2 won!
# 2499: Player 2 won!
# Player 1 wins 1251 times, with winrate of 0.5004

# %%
# create a game engine
engine = yut.engine.GameEngine()

# create two game players
player1 = MinimaxPlayer()
player2 = ExamplePlayer()

# simulate a game between two players with a given random seed
num_trial = 1000
win_rate = 0
for random_seed in range(num_trial):
	winner = engine.play( player1, player2, seed=random_seed )
	if winner == 0:
		win_rate += 1
		print( str(random_seed) + ": Player 1 won!" )
	else:
		print( str(random_seed) + ": Player 2 won!" )

print("Player 1 wins " + str(win_rate) + " times, with winrate of " + str(win_rate/num_trial) )
# Out:
# 0: Player 2 won!
# 1: Player 2 won!
# 2: Player 2 won!
# 3: Player 1 won!
# 4: Player 2 won!
# 5: Player 2 won!
# 6: Player 2 won!
# 7: Player 2 won!
# 8: Player 2 won!
# 9: Player 2 won!
# 10: Player 1 won!
# 11: Player 1 won!
# 12: Player 2 won!
# 13: Player 2 won!
# 14: Player 2 won!
# 15: Player 2 won!
# 16: Player 1 won!
# 17: Player 2 won!
# 18: Player 2 won!
# 19: Player 1 won!
# 20: Player 1 won!
# 21: Player 2 won!
# 22: Player 1 won!
# 23: Player 1 won!
# 24: Player 2 won!
# 25: Player 1 won!
# 26: Player 1 won!
# 27: Player 2 won!
# 28: Player 1 won!
# 29: Player 1 won!
# 30: Player 2 won!
# 31: Player 2 won!
# 32: Player 1 won!
# 33: Player 2 won!
# 34: Player 2 won!
# 35: Player 2 won!
# 36: Player 2 won!
# 37: Player 2 won!
# 38: Player 1 won!
# 39: Player 1 won!
# 40: Player 2 won!
# 41: Player 1 won!
# 42: Player 2 won!
# 43: Player 1 won!
# 44: Player 2 won!
# 45: Player 1 won!
# 46: Player 1 won!
# 47: Player 2 won!
# 48: Player 1 won!
# 49: Player 2 won!
# 50: Player 2 won!
# 51: Player 1 won!
# 52: Player 2 won!
# 53: Player 1 won!
# 54: Player 1 won!
# 55: Player 2 won!
# 56: Player 2 won!
# 57: Player 1 won!
# 58: Player 2 won!
# 59: Player 2 won!
# 60: Player 1 won!
# 61: Player 1 won!
# 62: Player 1 won!
# 63: Player 1 won!
# 64: Player 1 won!
# 65: Player 1 won!
# 66: Player 1 won!
# 67: Player 1 won!
# 68: Player 2 won!
# 69: Player 2 won!
# 70: Player 1 won!
# 71: Player 1 won!
# 72: Player 1 won!
# 73: Player 1 won!
# 74: Player 2 won!
# 75: Player 1 won!
# 76: Player 2 won!
# 77: Player 1 won!
# 78: Player 2 won!
# 79: Player 1 won!
# 80: Player 1 won!
# 81: Player 1 won!
# 82: Player 1 won!
# 83: Player 1 won!
# 84: Player 2 won!
# 85: Player 1 won!
# 86: Player 2 won!
# 87: Player 1 won!
# 88: Player 1 won!
# 89: Player 1 won!
# 90: Player 2 won!
# 91: Player 1 won!
# 92: Player 2 won!
# 93: Player 2 won!
# 94: Player 1 won!
# 95: Player 1 won!
# 96: Player 1 won!
# 97: Player 1 won!
# 98: Player 2 won!
# 99: Player 1 won!
# 229: Player 1 won!
# 230: Player 2 won!
# 231: Player 2 won!
# 232: Player 1 won!
# 233: Player 2 won!
# 234: Player 1 won!
# 235: Player 1 won!
# 236: Player 2 won!
# 237: Player 1 won!
# 238: Player 2 won!
# 239: Player 1 won!
# 240: Player 2 won!
# 241: Player 1 won!
# 242: Player 1 won!
# 243: Player 2 won!
# 244: Player 1 won!
# 245: Player 1 won!
# 246: Player 2 won!
# 247: Player 2 won!
# 248: Player 2 won!
# 249: Player 2 won!
# 250: Player 1 won!
# 251: Player 1 won!
# 252: Player 2 won!
# 253: Player 1 won!
# 254: Player 2 won!
# 255: Player 2 won!
# 256: Player 1 won!
# 257: Player 2 won!
# 258: Player 1 won!
# 259: Player 1 won!
# 260: Player 1 won!
# 261: Player 2 won!
# 262: Player 2 won!
# 263: Player 1 won!
# 264: Player 1 won!
# 265: Player 1 won!
# 266: Player 2 won!
# 267: Player 2 won!
# 268: Player 1 won!
# 269: Player 1 won!
# 270: Player 2 won!
# 271: Player 2 won!
# 272: Player 2 won!
# 273: Player 2 won!
# 274: Player 2 won!
# 275: Player 1 won!
# 276: Player 2 won!
# 277: Player 2 won!
# 278: Player 2 won!
# 279: Player 1 won!
# 280: Player 2 won!
# 281: Player 2 won!
# 282: Player 2 won!
# 283: Player 2 won!
# 284: Player 2 won!
# 285: Player 1 won!
# 286: Player 1 won!
# 287: Player 1 won!
# 288: Player 1 won!
# 289: Player 1 won!
# 290: Player 2 won!
# 291: Player 2 won!
# 292: Player 2 won!
# 293: Player 2 won!
# 294: Player 2 won!
# 295: Player 1 won!
# 296: Player 2 won!
# 297: Player 1 won!
# 298: Player 2 won!
# 299: Player 2 won!
# 300: Player 2 won!
# 301: Player 1 won!
# 302: Player 2 won!
# 303: Player 1 won!
# 304: Player 2 won!
# 305: Player 1 won!
# 306: Player 1 won!
# 307: Player 1 won!
# 308: Player 1 won!
# 309: Player 2 won!
# 310: Player 2 won!
# 311: Player 2 won!
# 312: Player 2 won!
# 313: Player 1 won!
# 314: Player 2 won!
# 315: Player 2 won!
# 316: Player 1 won!
# 317: Player 2 won!
# 318: Player 1 won!
# 319: Player 2 won!
# 320: Player 1 won!
# 321: Player 1 won!
# 322: Player 2 won!
# 323: Player 2 won!
# 324: Player 1 won!
# 325: Player 2 won!
# 326: Player 2 won!
# 327: Player 2 won!
# 328: Player 2 won!
# 329: Player 1 won!
# 330: Player 2 won!
# 331: Player 2 won!
# 332: Player 1 won!
# 333: Player 1 won!
# 334: Player 2 won!
# 335: Player 1 won!
# 336: Player 1 won!
# 337: Player 1 won!
# 338: Player 2 won!
# 339: Player 2 won!
# 340: Player 1 won!
# 341: Player 1 won!
# 342: Player 1 won!
# 343: Player 2 won!
# 344: Player 1 won!
# 345: Player 2 won!
# 346: Player 2 won!
# 347: Player 2 won!
# 348: Player 2 won!
# 349: Player 1 won!
# 350: Player 2 won!
# 351: Player 2 won!
# 352: Player 2 won!
# 353: Player 2 won!
# 354: Player 1 won!
# 355: Player 2 won!
# 356: Player 2 won!
# 357: Player 2 won!
# 744: Player 2 won!
# 745: Player 1 won!
# 746: Player 2 won!
# 747: Player 1 won!
# 748: Player 2 won!
# 749: Player 2 won!
# 750: Player 2 won!
# 751: Player 1 won!
# 752: Player 1 won!
# 753: Player 1 won!
# 754: Player 1 won!
# 755: Player 2 won!
# 756: Player 2 won!
# 757: Player 2 won!
# 758: Player 2 won!
# 759: Player 2 won!
# 760: Player 2 won!
# 761: Player 2 won!
# 762: Player 1 won!
# 763: Player 2 won!
# 764: Player 2 won!
# 765: Player 2 won!
# 766: Player 1 won!
# 767: Player 1 won!
# 768: Player 2 won!
# 769: Player 1 won!
# 770: Player 2 won!
# 771: Player 2 won!
# 772: Player 1 won!
# 773: Player 2 won!
# 774: Player 2 won!
# 775: Player 1 won!
# 776: Player 1 won!
# 777: Player 2 won!
# 778: Player 1 won!
# 779: Player 2 won!
# 780: Player 1 won!
# 781: Player 1 won!
# 782: Player 2 won!
# 783: Player 1 won!
# 784: Player 1 won!
# 785: Player 2 won!
# 786: Player 2 won!
# 787: Player 1 won!
# 788: Player 2 won!
# 789: Player 1 won!
# 790: Player 2 won!
# 791: Player 2 won!
# 792: Player 2 won!
# 793: Player 2 won!
# 794: Player 2 won!
# 795: Player 2 won!
# 796: Player 1 won!
# 797: Player 1 won!
# 798: Player 1 won!
# 799: Player 2 won!
# 800: Player 1 won!
# 801: Player 1 won!
# 802: Player 2 won!
# 803: Player 1 won!
# 804: Player 2 won!
# 805: Player 2 won!
# 806: Player 1 won!
# 807: Player 1 won!
# 808: Player 2 won!
# 809: Player 2 won!
# 810: Player 1 won!
# 811: Player 1 won!
# 812: Player 2 won!
# 813: Player 1 won!
# 814: Player 1 won!
# 815: Player 2 won!
# 816: Player 2 won!
# 817: Player 2 won!
# 818: Player 1 won!
# 819: Player 1 won!
# 820: Player 2 won!
# 821: Player 2 won!
# 822: Player 1 won!
# 823: Player 1 won!
# 824: Player 2 won!
# 825: Player 1 won!
# 826: Player 2 won!
# 827: Player 1 won!
# 828: Player 2 won!
# 829: Player 2 won!
# 830: Player 2 won!
# 831: Player 1 won!
# 832: Player 2 won!
# 833: Player 1 won!
# 834: Player 1 won!
# 835: Player 1 won!
# 836: Player 1 won!
# 837: Player 2 won!
# 838: Player 2 won!
# 839: Player 2 won!
# 840: Player 2 won!
# 841: Player 1 won!
# 842: Player 1 won!
# 843: Player 2 won!
# 844: Player 1 won!
# 845: Player 1 won!
# 846: Player 2 won!
# 847: Player 1 won!
# 848: Player 2 won!
# 849: Player 2 won!
# 850: Player 2 won!
# 851: Player 1 won!
# 852: Player 2 won!
# 853: Player 2 won!
# 854: Player 2 won!
# 855: Player 1 won!
# 856: Player 2 won!
# 857: Player 2 won!
# 858: Player 2 won!
# 859: Player 1 won!
# 860: Player 1 won!
# 861: Player 1 won!
# 862: Player 1 won!
# 863: Player 2 won!
# 864: Player 2 won!
# 865: Player 1 won!
# 866: Player 1 won!
# 867: Player 1 won!
# 868: Player 2 won!
# 869: Player 2 won!
# 870: Player 1 won!
# 871: Player 1 won!
# 872: Player 1 won!
# 873: Player 2 won!
# 874: Player 1 won!
# 875: Player 2 won!
# 876: Player 2 won!
# 877: Player 1 won!
# 878: Player 2 won!
# 879: Player 2 won!
# 880: Player 2 won!
# 881: Player 2 won!
# 882: Player 1 won!
# 883: Player 2 won!
# 884: Player 1 won!
# 885: Player 1 won!
# 886: Player 2 won!
# 887: Player 1 won!
# 888: Player 2 won!
# 889: Player 1 won!
# 890: Player 2 won!
# 891: Player 2 won!
# 892: Player 1 won!
# 893: Player 2 won!
# 894: Player 2 won!
# 895: Player 2 won!
# 896: Player 1 won!
# 897: Player 1 won!
# 898: Player 1 won!
# 899: Player 1 won!
# 900: Player 2 won!
# 901: Player 1 won!
# 902: Player 2 won!
# 903: Player 1 won!
# 904: Player 1 won!
# 905: Player 1 won!
# 906: Player 1 won!
# 907: Player 1 won!
# 908: Player 2 won!
# 909: Player 1 won!
# 910: Player 1 won!
# 911: Player 1 won!
# 912: Player 1 won!
# 913: Player 2 won!
# 914: Player 1 won!
# 915: Player 2 won!
# 916: Player 1 won!
# 917: Player 2 won!
# 918: Player 2 won!
# 919: Player 1 won!
# 920: Player 2 won!
# 921: Player 2 won!
# 922: Player 1 won!
# 923: Player 1 won!
# 924: Player 2 won!
# 925: Player 2 won!
# 926: Player 1 won!
# 927: Player 2 won!
# 928: Player 2 won!
# 929: Player 1 won!
# 930: Player 1 won!
# 931: Player 2 won!
# 932: Player 2 won!
# 933: Player 1 won!
# 934: Player 2 won!
# 935: Player 1 won!
# 936: Player 2 won!
# 937: Player 2 won!
# 938: Player 1 won!
# 939: Player 2 won!
# 940: Player 2 won!
# 941: Player 2 won!
# 942: Player 1 won!
# 943: Player 1 won!
# 944: Player 1 won!
# 945: Player 2 won!
# 946: Player 2 won!
# 947: Player 1 won!
# 948: Player 1 won!
# 949: Player 2 won!
# 950: Player 2 won!
# 951: Player 1 won!
# 952: Player 2 won!
# 953: Player 1 won!
# 954: Player 1 won!
# 955: Player 1 won!
# 956: Player 1 won!
# 957: Player 2 won!
# 958: Player 1 won!
# 959: Player 2 won!
# 960: Player 1 won!
# 961: Player 1 won!
# 962: Player 1 won!
# 963: Player 2 won!
# 964: Player 2 won!
# 965: Player 1 won!
# 966: Player 2 won!
# 967: Player 2 won!
# 968: Player 2 won!
# 969: Player 2 won!
# 970: Player 2 won!
# 971: Player 1 won!
# 972: Player 2 won!
# 973: Player 1 won!
# 974: Player 1 won!
# 975: Player 2 won!
# 976: Player 1 won!
# 977: Player 1 won!
# 978: Player 2 won!
# 979: Player 2 won!
# 980: Player 2 won!
# 981: Player 2 won!
# 982: Player 1 won!
# 983: Player 1 won!
# 984: Player 2 won!
# 985: Player 2 won!
# 986: Player 1 won!
# 987: Player 1 won!
# 988: Player 1 won!
# 989: Player 2 won!
# 990: Player 1 won!
# 991: Player 2 won!
# 992: Player 1 won!
# 993: Player 1 won!
# 994: Player 1 won!
# 995: Player 2 won!
# 996: Player 2 won!
# 997: Player 1 won!
# 998: Player 2 won!
# 999: Player 2 won!
# Player 1 wins 469 times, with winrate of 0.469
